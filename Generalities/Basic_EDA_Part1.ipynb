# %% [markdown]
# #Libraries Importation

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/dataset_ejemplo.csv")
#df = pd.read_excel('filename.xlsx') Excel
#df = pd.read_sql(query, connection) Base de datos SQL

# %% [markdown]
# #Data Inspection

# %%
df.head()
# Out:
#    Edad      Ingresos  Puntuacion_de_satisfaccion
# 0    56  47476.923679                           7
# 1    46  67471.529683                           9
# 2    32  46313.784689                           9
# 3    25  38454.983395                           3
# 4    38  68182.585132                           3

# %%
df.tail()
# Out:
#     Edad      Ingresos  Puntuacion_de_satisfaccion
# 95    59  42163.077807                           9
# 96    56  50195.508496                           8
# 97    58  55666.543880                           7
# 98    45  50942.368996                           9
# 99    24  57523.945480                           4

# %%
df.dtypes
# Out:
# Edad                            int64
# Ingresos                      float64
# Puntuacion_de_satisfaccion      int64
# dtype: object

# %%
df.describe()
# Out:
#              Edad      Ingresos  Puntuacion_de_satisfaccion
# count  100.000000    100.000000                  100.000000
# mean    37.910000  50125.408702                    4.780000
# std     12.219454  14684.490603                    2.680193
# min     18.000000  12518.612875                    1.000000
# 25%     26.750000  40689.408589                    3.000000
# 50%     38.000000  49719.768392                    4.500000
# 75%     46.250000  60624.020802                    7.000000
# max     59.000000  82380.927850                    9.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Edad                        100 non-null    int64
#  1   Ingresos                    100 non-null    float64
#  2   Puntuacion_de_satisfaccion  100 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 2.5 KB

# %% [markdown]
# #Data Cleaning

# %%
#Check for Missing Values:
df.isnull().sum()
# Out:
# Edad                          0
# Ingresos                      0
# Puntuacion_de_satisfaccion    0
# dtype: int64

# %%
#Fill Missing Values:
df.fillna(value=1)
# Out:
#     Edad      Ingresos  Puntuacion_de_satisfaccion
# 0     56  47476.923679                           7
# 1     46  67471.529683                           9
# 2     32  46313.784689                           9
# 3     25  38454.983395                           3
# 4     38  68182.585132                           3
# ..   ...           ...                         ...
# 95    59  42163.077807                           9
# 96    56  50195.508496                           8
# 97    58  55666.543880                           7
# 98    45  50942.368996                           9
# 99    24  57523.945480                           4
#
# [100 rows x 3 columns]

# %%
#Drop Missing Values:
df.dropna()
# Out:
#     Edad      Ingresos  Puntuacion_de_satisfaccion
# 0     56  47476.923679                           7
# 1     46  67471.529683                           9
# 2     32  46313.784689                           9
# 3     25  38454.983395                           3
# 4     38  68182.585132                           3
# ..   ...           ...                         ...
# 95    59  42163.077807                           9
# 96    56  50195.508496                           8
# 97    58  55666.543880                           7
# 98    45  50942.368996                           9
# 99    24  57523.945480                           4
#
# [100 rows x 3 columns]

# %%
#Rename columns
df.rename(columns={'Puntuacion_de_satisfaccion': 'Satisfaccion'})
# Out:
#     Edad      Ingresos  Satisfaccion
# 0     56  47476.923679             7
# 1     46  67471.529683             9
# 2     32  46313.784689             9
# 3     25  38454.983395             3
# 4     38  68182.585132             3
# ..   ...           ...           ...
# 95    59  42163.077807             9
# 96    56  50195.508496             8
# 97    58  55666.543880             7
# 98    45  50942.368996             9
# 99    24  57523.945480             4
#
# [100 rows x 3 columns]

# %%
#Drop columns
#df.drop(columns=['column_name'])

# %% [markdown]
# #Data Transformation

# %%
#Apply Function:
df['Ingresos'].apply(lambda x: round(x))
# Out:
# 0     47477
# 1     67472
# 2     46314
# 3     38455
# 4     68183
#       ...
# 95    42163
# 96    50196
# 97    55667
# 98    50942
# 99    57524
# Name: Ingresos, Length: 100, dtype: int64

# %%
#Group by and aggregate
df.groupby('Ingresos').agg({'Ingresos':'sum'})
# Out:
#                   Ingresos
# Ingresos
# 12518.612875  12518.612875
# 12954.517024  12954.517024
# 18626.004955  18626.004955
# 19333.654673  19333.654673
# 26387.670696  26387.670696
# ...                    ...
# 76914.212645  76914.212645
# 78084.786760  78084.786760
# 79007.597014  79007.597014
# 79176.734217  79176.734217
# 82380.927850  82380.927850
#
# [100 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Edad                        100 non-null    int64
#  1   Ingresos                    100 non-null    float64
#  2   Puntuacion_de_satisfaccion  100 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 2.5 KB

# %%
#Pivot tables
df.pivot_table(index='Ingresos', values='Edad', aggfunc='mean')
# Out:
#               Edad
# Ingresos
# 12518.612875    31
# 12954.517024    41
# 18626.004955    34
# 19333.654673    28
# 26387.670696    36
# ...            ...
# 76914.212645    47
# 78084.786760    52
# 79007.597014    46
# 79176.734217    37
# 82380.927850    32
#
# [100 rows x 1 columns]

# %%
#Merge DataFrames
#pd.merge(df1, df2, on='column')

# %%
#Concatenate DataFrames
#pd.concat([df1,df2])

# %% [markdown]
# #Data Visualization Integration

# %%
#Histogram 1
df['Edad'].hist()
# Out:
# <Axes: >

# %%
#Histogram 2
df['Ingresos'].hist()
# Out:
# <Axes: >

# %%
#Boxplot
df.boxplot(column=['Ingresos', 'Edad'])
# Out:
# <Axes: >

# %%
#Scatter Plot
df.plot.scatter(x = 'Edad', y = 'Ingresos')
# Out:
# <Axes: xlabel='Edad', ylabel='Ingresos'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Edad                        100 non-null    int64
#  1   Ingresos                    100 non-null    float64
#  2   Puntuacion_de_satisfaccion  100 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 2.5 KB

# %%
df.plot.line()
# Out:
# <Axes: >
