# %% [markdown]
# ##ICE TRIGGER

# %% [markdown]
# This example is for the ICE Trigger task. Given a provided data as indicated in the slides, you should analyze if the prompt triggers a proper Implicit Code Execution (ICE).

# %% [markdown]
# ###*PROVIDED DATA:*
#
# User: Can you help me analyze this data?
# ```python
# data = {
#     'x': [1, 2, 3, 4, 5],
#     'y': [2, 4, 6, 8, 10]
# }
# ```
# System: Sure, what kind of analysis do you want to do?
#
# User: I want to see the correlation between the variables x and y.
#
# System: Okay, I can plot a scatter diagram for you. Do you want to see the correlation coefficient as well?
#
# User: Yes, please.

# %% [markdown]
# ### *REQUIRED INFORMATION:*
#
# IS THE PROMPT WRITTEN IN ENGLISH?: No / <font color='green'>Yes</font>
#
# WOULD CODE EXECUTION FOR DATA ANALYSIS, MANIPULATION, OR PLOT/GRAPH GENERATION HELP WITH THIS QUERY? No / <font color='green'>Yes</font> / Missing Data
#
# SELECT ALL THE CATEGORIES THAT ADEQUATELY DESCRIBE PROMPTS: <font color='green'>Data Analysis</font> / <font color='green'>Plot/Graph Generation</font> / Data Manipulation / Other

# %% [markdown]
# ---------------

# %% [markdown]
# ##ICE CORRECTNESS REWRITE

# %% [markdown]
# This example is for the ICE Correctness Rewrite task. Given a provided data as indicated in the slides, you should rewrite and check the correctness of the new prompt and its answer.

# %% [markdown]
# ###*PROVIDED DATA:*
# PROMPT: What is the average age of customers in the dataset “customer_data.csv”?

# %% [markdown]
# ### *REQUIRED INFORMATION:*
#
# IS THE PROMPT CORRECT? <font color='green'>No</font>
#
# REWRITE A CORRECT VERSION OF THE PROMPT:  <font color='green'>Write a line of Python code that calculates and prints the average age of customers in the dataset “customer_data.csv”.</font>
#
# INPUT FILE REFERENCE IN THE PROMPT: Implicit Reference / <font color='green'>Explicit Reference</font> / No Reference / No input file
#
# DOES THE PROMPT EXPLICITLY REQUESTS FOR CODE IN THE RESPONSE?  No
#
# IS THE DESIRED (GOLDEN) ANSWER CORRECT? Yes / No
#
# PASTE THE CODE YOU USED TO SOLVE THIS PROBLEM:
# ```python
# print(pd.read_csv("customer_data.csv")['age'].mean())
# ```

# %% [markdown]
# -----------------------

# %% [markdown]
# ##ICE CORRECTNESS RATING

# %% [markdown]
# This example is for the ICE Correctness Rating task. Given a provided data as indicated in the slides, you should compare the answers of two models (A & B) to help you get the right answer.

# %% [markdown]
# PROMPT CATEGORY: Data Analysis
#
# PROMPT: Calculate the mean of the column “age” in the dataset “titanic.csv”.
#
# DESIRED ANSWER (GOLDEN): The mean of the “age” column is X.
#
# RENSPONSE A:
#
# ```python
# import pandas as pd
#
# df = pd.read_csv("titanic.csv")
# mean_age = df["age"].mean()
# print(f"The mean of the 'age' column is {mean_age}")
# ```
# RESPONSE B:
#
# ```python
# import pandas as pd
#
# df = pd.read_csv("titanic.csv")
# mean_age = df["age"].mean()
# print(f"The average age is {mean_age}")
# ```
# Model B Correctness: <font color='green'>Fully Correct</font>
#
# Is the Model B response correct?: <font color='green'>Yes</font>
#
# Is the code execution in the Model A response correct?: <font color='green'>yes</font>
#
# Does the Model A response cause the Model B response to go wrong?: <font color='red'>No</font>
