# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {
        'name': ['Peter', 'Juan', 'Melisa', 'Ana', 'Charles', 'Maria', 'Sonia', 'Peter', 'Melisa', 'Ana', 'Ana'],
        'age': [23, 20, 34, 40, 45, 21, 67, 55, 89, 3, 14]
    },
    index=range(10, 21)
)
df
# Out:
#        name  age
# 10    Peter   23
# 11     Juan   20
# 12   Melisa   34
# 13      Ana   40
# 14  Charles   45
# 15    Maria   21
# 16    Sonia   67
# 17    Peter   55
# 18   Melisa   89
# 19      Ana    3
# 20      Ana   14

# %% [markdown]
# ## loc vs iloc

# %%
df.loc[[10, 11, 14], ['age', 'name']]
# Out:
#     age     name
# 10   23    Peter
# 11   20     Juan
# 14   45  Charles

# %%
df.iloc[[0,1,4], [1]]
# Out:
#     age
# 10   23
# 11   20
# 14   45

# %% [markdown]
# ## Change DataFrame values: mask vs loc/iloc

# %%
age_mask = df['age'] > 25
new_df = df[age_mask]
new_df
# Out:
#        name  age
# 12   Melisa   34
# 13      Ana   40
# 14  Charles   45
# 16    Sonia   67
# 17    Peter   55
# 18   Melisa   89

# %%
new_df['name'] = '...'
# Out:
# C:\Users\afeli\AppData\Local\Temp\ipykernel_17508\2385480902.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['name'] = '...'

# %%
new_df
# Out:
#    name  age
# 12  ...   34
# 13  ...   40
# 14  ...   45
# 16  ...   67
# 17  ...   55
# 18  ...   89

# %%
df
# Out:
#        name  age
# 10    Peter   23
# 11     Juan   20
# 12   Melisa   34
# 13      Ana   40
# 14  Charles   45
# 15    Maria   21
# 16    Sonia   67
# 17    Peter   55
# 18   Melisa   89
# 19      Ana    3
# 20      Ana   14

# %%
age_mask = df['age'] > 25
df[age_mask]['name'] = '...'
df
# Out:
# C:\Users\afeli\AppData\Local\Temp\ipykernel_17508\3253659137.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[age_mask]['name'] = '...'
#        name  age
# 10    Peter   23
# 11     Juan   20
# 12   Melisa   34
# 13      Ana   40
# 14  Charles   45
# 15    Maria   21
# 16    Sonia   67
# 17    Peter   55
# 18   Melisa   89
# 19      Ana    3
# 20      Ana   14

# %%
age_mask = df['age'] > 25
df.loc[age_mask, 'name'] = '...'
df
# Out:
#      name  age
# 10  Peter   23
# 11   Juan   20
# 12    ...   34
# 13    ...   40
# 14    ...   45
# 15  Maria   21
# 16    ...   67
# 17    ...   55
# 18    ...   89
# 19    Ana    3
# 20    Ana   14

# %%
new_df['name'] = '...'
new_df
# Out:
# C:\Users\afeli\AppData\Local\Temp\ipykernel_17508\1976493848.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['name'] = '...'
#    name  age
# 12  ...   34
# 13  ...   40
# 14  ...   45
# 16  ...   67
# 17  ...   55
# 18  ...   89

# %%
df
# Out:
#      name  age
# 10  Peter   23
# 11   Juan   20
# 12    ...   34
# 13    ...   40
# 14    ...   45
# 15  Maria   21
# 16    ...   67
# 17    ...   55
# 18    ...   89
# 19    Ana    3
# 20    Ana   14

# %%
df1 = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K3"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }
)


df2 = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K4"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }
)

# %% [markdown]
# ### Dataframe queries

# %% [markdown]
# Pandas allow us to filter data by performing queries on dataframes in a Pythonic way.

# %% [markdown]
# For instance, if we want to get the persons whose age is greater than 20, we can execute the following query:

# %%
condition = ["Peter", "Maria"]

# %%
df.query('age > 20')
# Out:
#      name  age
# 10  Peter   23
# 12    ...   34
# 13    ...   40
# 14    ...   45
# 15  Maria   21
# 16    ...   67
# 17    ...   55
# 18    ...   89

# %% [markdown]
# We can also use variables in the environment, and add multiple conditions. For instance, if we want to extend our previous query to also filter all the persons named Peter or Maria, we can do the following:

# %%
df.query('age > 20 and name not in @condition')
# Out:
#    name  age
# 12  ...   34
# 13  ...   40
# 14  ...   45
# 16  ...   67
# 17  ...   55
# 18  ...   89
