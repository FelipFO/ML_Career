# %% [markdown]
# # Limits & Derivatives

# %% [markdown]
# This topic introduces the mathematical field of calculus -- the study of rates of change -- from the ground up. It is essential because computing derivatives via differentiation is the basis of optimizing most machine learning algorithms, including those used in deep learning such as backpropagation and stochastic gradient descent.

# %% [markdown]
# ## Segment 1: Limits

# %% [markdown]
# ### The Calculus of Infinitesimals

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10, 10, 10000) # start, finish, n points

# %%
x
# Out:
# array([-10.       ,  -9.9979998,  -9.9959996, ...,   9.9959996,
#          9.9979998,  10.       ])

# %% [markdown]
# If $y = x^2 + 2x + 2$:

# %%
y = x**2 + 2*x + 2

# %%
fig, ax = plt.subplots()
_ = ax.plot(x,y)

# %% [markdown]
# * There are no straight lines on the curve.
# * If we zoom in _infinitely_ close, however, we observe curves that _approach_ lines.
# * This enables us to find a slope $m$ (tangent) anywhere on the curve, including to identify where $m = 0$:

# %%
fig, ax = plt.subplots()
ax.set_xlim([-2, -0])
ax.set_ylim([0, 2])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.5, -0.5])
ax.set_ylim([0.5, 1.5])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.1, -0.9])
ax.set_ylim([0.9, 1.1])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.01, -0.99])
ax.set_ylim([0.99, 1.01])
_ = ax.plot(x,y)

# %% [markdown]
# ### Limits

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-5, 10)
plt.ylim(-10, 80)
plt.axvline(x=5, color='green', linestyle='--')
plt.axhline(y=37, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %% [markdown]
# $$\lim_{x \to 1} \frac{x^2 - 1}{x - 1}$$

# %%
def my_fxn(my_x):
    my_y = (my_x**2 - 1)/(my_x - 1)
    return my_y

# %%
my_fxn(2)
# Out:
# 3.0

# %%
my_fxn(0.9)
# Out:
# 1.9

# %%
my_fxn(0.999)
# Out:
# 1.9989999999999712

# %%
my_fxn(1.1)
# Out:
# 2.1

# %%
my_fxn(1.001)
# Out:
# 2.0009999999999177

# %%
y = my_fxn(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-1, 5)
plt.ylim(-1, 5)
plt.axvline(x=1, color='purple', linestyle='--')
plt.axhline(y=2, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %% [markdown]
# $$\lim_{x \to 0} \frac{\text{sin } x}{x}$$

# %%
def sin_fxn(my_x):
    my_y = np.sin(my_x)/my_x
    return my_y

# %%
# Uncommenting the following line results in a 'division by zero' error:
y = sin_fxn(0)
# Out:
# C:\Users\afeli\AppData\Local\Temp\ipykernel_13580\2071130323.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   my_y = np.sin(my_x)/my_x

# %%
sin_fxn(0.1)
# Out:
# 0.9983341664682815

# %%
sin_fxn(0.001)
# Out:
# 0.9999998333333416

# %%
sin_fxn(-0.1)
# Out:
# 0.9983341664682815

# %%
sin_fxn(-0.001)
# Out:
# 0.9999998333333416

# %%
y = sin_fxn(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-1, 2)
plt.axvline(x=0, color='purple', linestyle='--')
plt.axhline(y=1, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %% [markdown]
# **Exercises:**
#
# Evaluate the limits below using techniques from the slides or above.
#
# 1. $$ \lim_{x \to 0} \frac{x^2-1}{x-1} $$
# 2. $$ \lim_{x \to -5} \frac{x^2-25}{x+5} $$
# 3. $$ \lim_{x \to 4} \frac{x^2 -2x -8}{x-4} $$
# 4. $$ \lim_{x \to 0} \frac{25}{x} $$

# %% [markdown]
# ## Segment 2: Computing Derivatives with Differentiation

# %% [markdown]
# Let's bring back our ol' buddy $y = x^2 + 2x + 2$:

# %%
def f(my_x):
    my_y = my_x**2 + 2*my_x + 2
    return my_y

# %%
y = f(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
_ = ax.plot(x,y)

# %% [markdown]
# Let's identify the slope where, say, $x = 2$.

# %% [markdown]
# First, let's determine what $y$ is:

# %%
f(2)
# Out:
# 10

# %% [markdown]
# Cool. Let's call this point $P$, which is located at (2, 10):

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10) # new
_ = ax.plot(x,y)

# %% [markdown]
# The _delta method_ uses the difference between two points to calculate slope. To illustrate this, let's define another point, $Q$ where, say, $x = 5$.

# %%
f(5)
# Out:
# 37

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10)
plt.scatter(5, 37, c = 'orange', zorder=3) # new
_ = ax.plot(x,y)

# %% [markdown]
# To find the slope $m$ between points $P$ and $Q$:
# $$m = \frac{\text{change in }y}{\text{change in }x} = \frac{\Delta y}{\Delta x} = \frac{y_2 - y_1}{x_2 - x_1} = \frac{37-10}{5-2} = \frac{27}{3} = 9$$

# %%
m = (37-10)/(5-2)
m
# Out:
# 9.0

# %% [markdown]
# To plot the line that passes through $P$ and $Q$, we can rearrange the equation of a line $y = mx + b$ to solve for $b$:
# $$b = y - mx$$

# %%
b = 37-m*5
b
# Out:
# -8.0

# %%
line_y = m*x + b

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10)
plt.scatter(5, 37, c='orange', zorder=3)
plt.ylim(-5, 150) # new
plt.plot(x, line_y, c='orange') # new
_ = ax.plot(x,y)

# %% [markdown]
# The closer $Q$ becomes to $P$, the closer the slope $m$ comes to being the true tangent of the point $P$. Let's demonstrate this with another point $Q$ at $x = 2.1$.

# %% [markdown]
# Previously, our $\Delta x$ between $Q$ and $P$ was equal to 3. Now it is much smaller: $$\Delta x = x_2 - x_1 = 2.1 - 2 = 0.1 $$

# %%
f(2.1)
# Out:
# 10.61

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10)
plt.scatter(2.1, 10.61, c = 'orange', zorder=3)
_ = ax.plot(x,y)

# %%
m = (10.61-10)/(2.1-2)
m
# Out:
# 6.099999999999989

# %%
b = 10.61-m*2.1
b
# Out:
# -2.199999999999978

# %%
line_y = m*x + b

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10)
plt.scatter(2.1, 10.61, c='orange', zorder=3)
plt.ylim(-5, 150)
plt.plot(x, line_y, c='orange', zorder=3)
_ = ax.plot(x,y)

# %% [markdown]
# The closer $Q$ becomes to $P$ (i.e., $\Delta x$ approaches 0), the clearer it becomes that the slope $m$ at point $P$ = (2, 10) is equal to 6.

# %% [markdown]
# Let's make $\Delta x$ extremely small, 0.000001, to illustrate this:

# %%
delta_x = 0.000001
delta_x
# Out:
# 1e-06

# %%
x1 = 2
y1 = 10

# %% [markdown]
# Rearranging $\Delta x = x_2 - x_1$, we can calculate $x_2$ for our point $Q$, which is now extremely close to $P$:
# $$x_2 = x_1 + \Delta x$$

# %%
x2 = x1 + delta_x
x2
# Out:
# 2.000001

# %% [markdown]
# $y_2$ for our point $Q$ can be obtained with the usual function $f(x)$:
# $$y_2 = f(x_2)$$

# %%
y2 = f(x2)
y2
# Out:
# 10.000006000001001

# %% [markdown]
# To find the slope $m$, we continue to use $$m = \frac{\Delta y}{\Delta x} = \frac{y_2 - y_1}{x_2 - x_1}$$

# %%
m = (y2 - y1)/(x2 - x1)
m
# Out:
# 6.000001000088901

# %%
x1 = 2
y1 = f(x1)
for delta in [5, 1, 0.1, 0.001, 0.00001]:
  x2 = x1 + delta
  y2 = f(x2)
  m = (y2 - y1)/(x2 - x1)
  print(m)
# Out:
# 11.0
# 7.0
# 6.099999999999989
# 6.00100000000014
# 6.00000999991201

# %% [markdown]
# Point $P$ is located at (-1, 1)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(x1, y1)

_ = ax.plot(x,y)

# %%
delta_x = 1e-06

# %%
x2 = x1 + delta_x
x2
# Out:
# 2.000001

# %%
y2 = f(x2)
y2
# Out:
# 10.000006000001001

# %% [markdown]
# Quick aside: Pertinent to defining differentiation as an equation, an alternative way to calculate $y_2$ is $f(x + \Delta x)$

# %%
y2 = f(x1 + delta_x)
y2
# Out:
# 10.000006000001001

# %% [markdown]
# Point $Q$ is at (-0.999999, 1.000000000001), extremely close to $P$.

# %%
m = (y2-y1)/(x2-x1)
m
# Out:
# 6.000001000088901

# %% [markdown]
# Therefore, as $x_2$ becomes infinitely close to $x_1$, it becomes clear that the slope $m$ at $x_1 = -1$ is equal to zero. Let's plot it out:

# %%
b = y2-m*x2
b
# Out:
# -2.000002000177801

# %%
line_y = m*x + b

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(x1, y1)
plt.scatter(x2, y2, c='orange', zorder=3)
plt.ylim(-5, 150)
plt.plot(x, line_y, c='orange', zorder=3)
_ = ax.plot(x,y)

# %% [markdown]
# As $Q$ becomes infinitely close to $P$:
# * $x_2$ - $x_1$ approaches 0
# * In other words, $\Delta x$ approaches 0
# * This can be denoted as $\Delta x \to 0$

# %% [markdown]
# Using the delta method, we've derived the definition of differentiation from first principles. The derivative of $y$ (denoted $dy$) with respect to $x$ (denoted $dx$) can be represented as:
# $$\frac{dy}{dx} = \lim_{\Delta x \to 0} \frac{\Delta y}{\Delta x}$$

# %% [markdown]
# Expanding $\Delta y$ out to $y_2 - y_1$:
# $$\frac{dy}{dx} = \lim_{\Delta x \to 0} \frac{y_2 - y_1}{\Delta x}$$

# %% [markdown]
# Finally, replacing $y_1$ with $f(x)$ and replacing $y_2$ with $f(x + \Delta x)$, we obtain a common representation of differentiation:
# $$\frac{dy}{dx} = \lim_{\Delta x \to 0} \frac{f(x + \Delta x) - f(x)}{\Delta x}$$

# %% [markdown]
# Let's observe the differentiation equation in action:

# %%
def diff_demo(my_f, my_x, my_delta):
    return (my_f(my_x + my_delta) - my_f(my_x)) / my_delta

# %%
deltas = [1, 0.1, 0.01, 0.001, 0.0001, 0.00001, 0.000001]

# %%
for delta in deltas:
    print(diff_demo(f, 2, delta))
# Out:
# 7.0
# 6.099999999999994
# 6.009999999999849
# 6.000999999999479
# 6.000100000012054
# 6.000009999951316
# 6.000001000927568

# %%
for delta in deltas:
    print(diff_demo(f, -1, delta))
# Out:
# 1.0
# 0.10000000000000009
# 0.009999999999998899
# 0.001000000000139778
# 9.99999993922529e-05
# 1.000000082740371e-05
# 1.000088900582341e-06

# %%
def f(x):
  return x**2

for delta in deltas:
    print(diff_demo(f, 5, delta))
# Out:
# 11.0
# 10.09999999999998
# 10.009999999999764
# 10.001000000002591
# 10.000099999984968
# 10.000009999444615
# 10.00000100148668

# %% [markdown]
# ## Segment 3: Automatic Differentiation

# %% [markdown]
# **TensorFlow** and **PyTorch** are the two most popular automatic differentiation libraries.

# %% [markdown]
# Let's use them to calculate $dy/dx$ at $x = 5$ where:

# %% [markdown]
# $$y = x^2$$

# %% [markdown]
# ### Autodiff with TensorFlow

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\afeli\anaconda3\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.23)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.6)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\afeli\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\afeli\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\afeli\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.3.2)
# Requirement already satisfied: scipy>=1.9 in c:\users\afeli\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.11.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\afeli\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\afeli\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\afeli\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\afeli\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\afeli\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\afeli\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\afeli\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\afeli\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\afeli\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\afeli\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\afeli\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\afeli\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\afeli\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\afeli\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\afeli\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\afeli\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\afeli\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)

# %%
import tensorflow as tf

# %%
x = tf.Variable(5.0)

# %%
with tf.GradientTape() as t:
    t.watch(x) # track forward pass
    y = x**2

# %%
t.gradient(y, x) # use autodiff
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.0>
